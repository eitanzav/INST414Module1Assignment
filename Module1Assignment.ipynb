# %% [markdown]
# Eitan Zavorin - Module 1 Assignment

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('/Users/eitanzavorin/Downloads/vgsales.csv')

df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df.drop_duplicates(subset=['Name'], inplace=True)

df.drop(columns=['EU_Sales', 'NA_Sales', 'JP_Sales', 'Other_Sales', 'Platform'], inplace=True)

df
# Out:
#         Rank                                               Name    Year  \
# 0          1                                         Wii Sports  2006.0
# 1          2                                  Super Mario Bros.  1985.0
# 2          3                                     Mario Kart Wii  2008.0
# 3          4                                  Wii Sports Resort  2009.0
# 4          5                           Pokemon Red/Pokemon Blue  1996.0
# ...      ...                                                ...     ...
# 16589  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...  2016.0
# 16590  16593  Eiyuu Densetsu: Sora no Kiseki Material Collec...  2007.0
# 16592  16595                                           Plushees  2008.0
# 16593  16596                 Woody Woodpecker in Crazy Castle 5  2002.0
# 16596  16599                                         Know How 2  2010.0
#
#               Genre           Publisher  Global_Sales
# ...

# %%
fps_df = df.loc[df['Genre'] == 'Shooter']
fps_df
# Out:
#         Rank                                 Name    Year    Genre  \
# 9         10                            Duck Hunt  1984.0  Shooter
# 29        30       Call of Duty: Modern Warfare 3  2011.0  Shooter
# 31        32              Call of Duty: Black Ops  2010.0  Shooter
# 33        34            Call of Duty: Black Ops 3  2015.0  Shooter
# 34        35           Call of Duty: Black Ops II  2012.0  Shooter
# ...      ...                                  ...     ...      ...
# 16339  16342           Command & Conquer Renegade  2002.0  Shooter
# 16440  16443           Bullet Soul: Tama Tamashii  2011.0  Shooter
# 16475  16478                        Space Raiders  2003.0  Shooter
# 16476  16479  DoDonPachi Daifukkatsu: Black Label  2011.0  Shooter
# 16585  16588                               Breach  2011.0  Shooter
#
#              Publisher  Global_Sales
# 9             Nintendo         28.31
# 29          Activision         14.76
# 31          Activision         14.64
# ...

# %%
top_10_games = fps_df.head(10)
print(top_10_games)
# Out:
#     Rank                            Name    Year    Genre  \
# 9     10                       Duck Hunt  1984.0  Shooter
# 29    30  Call of Duty: Modern Warfare 3  2011.0  Shooter
# 31    32         Call of Duty: Black Ops  2010.0  Shooter
# 33    34       Call of Duty: Black Ops 3  2015.0  Shooter
# 34    35      Call of Duty: Black Ops II  2012.0  Shooter
# 36    37  Call of Duty: Modern Warfare 2  2009.0  Shooter
# 43    44                          Halo 3  2007.0  Shooter
# 61    62            Call of Duty: Ghosts  2013.0  Shooter
# 62    63                     Halo: Reach  2010.0  Shooter
# 65    66                          Halo 4  2012.0  Shooter
#
#                  Publisher  Global_Sales
# 9                 Nintendo         28.31
# 29              Activision         14.76
# 31              Activision         14.64
# 33              Activision         14.24
# 34              Activision         14.03
# 36              Activision         13.51
# ...

# %%
plt.figure(figsize=(10, 6))
plt.bar(top_10_games['Name'], top_10_games['Global_Sales'], color='skyblue')
plt.xlabel('Game Name')
plt.ylabel('Global Sales (in millions)')
plt.title('Top 10 Highest Selling First-Person Shooter Games')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
publisher_sales = fps_df.groupby('Publisher')['Global_Sales'].sum()

# Select the top 5 publishers with the highest total sales
top_5_publishers = publisher_sales.nlargest(5)

# Plotting
plt.figure(figsize=(8, 6))
plt.pie(top_5_publishers, labels=top_5_publishers.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Top 5 Highest Selling Publishers (FPS ONLY)')
plt.show()

# %%
publisher_sales = df.groupby('Publisher')['Global_Sales'].sum()

# Select the top 5 publishers with the highest total sales
top_5_publishers = publisher_sales.nlargest(5)

# Plotting
plt.figure(figsize=(8, 6))
plt.pie(top_5_publishers, labels=top_5_publishers.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Top 5 Highest Selling Publishers (ALL GAMES)')
plt.show()
